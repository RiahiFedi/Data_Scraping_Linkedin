# %%
#Importing the needed packages and parameters 
from time import sleep
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import csv
import random
import pandas as pd
import parameters

# %%
driver = webdriver.Chrome('C:/Users/fedir/Data_Scraping_Linkedin/chromedriver')

# %%
#Asking the driver to open the given link
driver.get('https://www.linkedin.com')

#Locating and writing the username, while simulating keystrokes on the keyboard
username = driver.find_element_by_id('session_key')
username.send_keys(parameters.linkedin_username)

#Pausing the algorithm for a random duration.
sleep(random.randint(500,1000)/1000)

#Locating and writing the password, while simulating keystrokes on the keyboard
password = driver.find_element_by_id('session_password')
password.send_keys(parameters.linkedin_password)

sleep(random.randint(500,1000)/1000)

#Locating and pressing the Signin button
sign_in_button = driver.find_element_by_class_name('sign-in-form__submit-button')
sign_in_button.click()

# %%
#load the profile page
driver.get(linkedin_url)

# Scroll to the bottom of the page to make sure all the HTML is loaded properly using a smooth scroll function 
for i in range(3):
    sleep(random.randint(500,1000)/1000)
    scroll_down()

# assigning the source code for the webpage to variable sel
sel = driver.page_source
soup = BeautifulSoup(sel, 'lxml')

# %%
data = pd.read_csv('results_file0.csv')
df = data.head(10)
data.head(10)
# Out:
#    Unnamed: 0             name  \
# 0           0   IMEN BEN AHMED
# 1           1   Omar Ben Miled
# 2           2     Farah Gharbi
# 3           3        Ali Sabri
# 4           4  Ibrahim Dembele
# 5           5   Chaima Sellami
# 6           6    Ibtihel Shimi
# 7           7      Chadha Bani
# 8           8       Manu Badex
# 9           9    yahyaoui olfa
#
#                                        profile_title  \
# 0    Gestionnaire de portefeuille chez attijari bank
# 1  Responsable ressources humaines et formations ...
# 2  Software Engineering Student At Faculty of Mat...
# 3  Technicien supérieur en gestion de maintenance...
# 4                              Ex Général de l'armée
# 5      Directeur d'agence chez Attijari bank Tunisie
# 6                            ECM Architect chez CTIE
# 7  QA Analyst, Certified ISTQB® (open for new opp...
# 8                                                 --
# 9                     société  azzahra agro services
#
#                                      entreprise_name             duration  \
# 0                                      attijari bank   Apr 2008 – Present
# 1                             IRIS Junior Entreprise   Dec 2020 – Present
# 2                               Currently Unemployed                  NaN
# 3                                       Poids lourds             Jan 2018
# 4                                                NaN  May 2019 – Aug 2020
# 5                              Attijari bank Tunisie   Dec 2008 – Present
# 6                                               CTIE   Nov 2020 – Present
# 7  La Direction Générale des Impôts du Ministère ...   Dec 2018 – Present
# 8                                                NaN                  NaN
# 9                              Azzahra agro services   Feb 2019 – Present
#
#             experience                                          location  \
# 0   Apr 2008 – Present                                    Tunis, Tunisia
# 1   Feb 2021 – Present                         Sfax Governorate, Tunisia
# 2                  NaN                                    Tunis, Tunisia
# 3   Oct 2015 –Jan 2018                             Tunis, Tunis, Tunisia
# 4  May 2019 – Aug 2020                                               NaN
# 5   Dec 2008 – Present  Aryanah al-Madeenah, Ariana Governorate, Tunisia
# 6        2014– Present                Luxembourg, Luxembourg, Luxembourg
# 7   Jan 2013 – Present                             Tunis, Tunis, Tunisia
# 8                  NaN                                               NaN
# 9   Feb 2019 – Present                             Tunis, Tunis, Tunisia
#
#                                            education  nbr_employees  \
# 0                                                NaN         1138.0
# 1               école supérieure de commerce de Sfax           42.0
# 2  Faculté des Sciences Mathématiques, Physiques ...            NaN
# 3  Centre sectoriel de formation de la gestion de...          353.0
# 4  Centre sectoriel de formation de la gestion de...            NaN
# 5                                               IHEC          455.0
# 6  Ecole Supérieure Privée d'Ingénierie et de Tec...          201.0
# 7                  Institut supérieur d'informatique            NaN
# 8                  Institut supérieur d'informatique            NaN
# 9                                                NaN            NaN
#
#                          work_field  \
# 0                           Banking
# 1           Marketing & Advertising
# 2                               NaN
# 3  Transportation/Trucking/Railroad
# 4                               NaN
# 5                           Banking
# 6         Government Administration
# 7                               NaN
# 8                               NaN
# 9                               NaN
#
#                                         linkedin_url
# 0  https://www.linkedin.com/in/imen-ben-ahmed-118...
# 1  https://www.linkedin.com/in/omar-ben-miled-992...
# 2  https://www.linkedin.com/in/farah-gharbi?miniP...
# 3  https://www.linkedin.com/in/ali-sabri-565a6b1b...
# 4  https://www.linkedin.com/in/ibrahim-dembele-16...
# 5  https://www.linkedin.com/in/chaima-sellami-218...
# 6  https://www.linkedin.com/in/ibtihel-shimi-65a7...
# 7  https://www.linkedin.com/in/chadha-bani-bba891...
# 8  https://www.linkedin.com/in/manu-badex-87b1201...
# 9  https://www.linkedin.com/in/yahyaoui-olfa-5743...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'profile_title', 'entreprise_name', 'duration',
#        'experience', 'location', 'education', 'nbr_employees', 'work_field',
#        'linkedin_url'],
#       dtype='object')

# %%
df= df.loc[[0,1,3,5,6]]
df.drop(['Unnamed: 0'],axis = 1)
# Out:
#              name                                      profile_title  \
# 0  IMEN BEN AHMED    Gestionnaire de portefeuille chez attijari bank
# 1  Omar Ben Miled  Responsable ressources humaines et formations ...
# 3       Ali Sabri  Technicien supérieur en gestion de maintenance...
# 5  Chaima Sellami      Directeur d'agence chez Attijari bank Tunisie
# 6   Ibtihel Shimi                            ECM Architect chez CTIE
#
#           entreprise_name            duration          experience  \
# 0           attijari bank  Apr 2008 – Present  Apr 2008 – Present
# 1  IRIS Junior Entreprise  Dec 2020 – Present  Feb 2021 – Present
# 3            Poids lourds            Jan 2018  Oct 2015 –Jan 2018
# 5   Attijari bank Tunisie  Dec 2008 – Present  Dec 2008 – Present
# 6                    CTIE  Nov 2020 – Present       2014– Present
#
#                                            location  \
# 0                                    Tunis, Tunisia
# 1                         Sfax Governorate, Tunisia
# 3                             Tunis, Tunis, Tunisia
# 5  Aryanah al-Madeenah, Ariana Governorate, Tunisia
# 6                Luxembourg, Luxembourg, Luxembourg
#
#                                            education  nbr_employees  \
# 0                                                NaN         1138.0
# 1               école supérieure de commerce de Sfax           42.0
# 3  Centre sectoriel de formation de la gestion de...          353.0
# 5                                               IHEC          455.0
# 6  Ecole Supérieure Privée d'Ingénierie et de Tec...          201.0
#
#                          work_field  \
# 0                           Banking
# 1           Marketing & Advertising
# 3  Transportation/Trucking/Railroad
# 5                           Banking
# 6         Government Administration
#
#                                         linkedin_url
# 0  https://www.linkedin.com/in/imen-ben-ahmed-118...
# 1  https://www.linkedin.com/in/omar-ben-miled-992...
# 3  https://www.linkedin.com/in/ali-sabri-565a6b1b...
# 5  https://www.linkedin.com/in/chaima-sellami-218...
# 6  https://www.linkedin.com/in/ibtihel-shimi-65a7...

# %%
#load the post page
driver.get(urls[i])
sleep(random.randint(500,1000)/1000)
scroll_down()

# locate the reactions pannel
react_pannel = driver.find_element_by_class_name('social-details-social-counts')
react_pannel = react_pannel.find_element(By.XPATH, '//li[1]/button')
actions = ActionChains(driver)
actions.move_to_element(react_pannel).perform()
react_pannel.click()

# %%
data_rec = pd.read_csv('reactions.csv')
data_rec = data_rec.drop(['Unnamed: 0'],axis = 1)
data_rec.head(10)
# Out:
#               name                                       linkedin_url reaction
# 0   IMEN BEN AHMED  https://www.linkedin.com/in/imen-ben-ahmed-118...     LIKE
# 1   Omar Ben Miled  https://www.linkedin.com/in/omar-ben-miled-992...     LIKE
# 2     Farah Gharbi  https://www.linkedin.com/in/farah-gharbi?miniP...     LIKE
# 3        Ali Sabri  https://www.linkedin.com/in/ali-sabri-565a6b1b...     LIKE
# 4  Ibrahim Dembele  https://www.linkedin.com/in/ibrahim-dembele-16...     LIKE
# 5   Chaima Sellami  https://www.linkedin.com/in/chaima-sellami-218...     LIKE
# 6    Ibtihel Shimi  https://www.linkedin.com/in/ibtihel-shimi-65a7...  EMPATHY
# 7      Chadha Bani  https://www.linkedin.com/in/chadha-bani-bba891...   PRAISE
# 8       Manu Badex  https://www.linkedin.com/in/manu-badex-87b1201...     LIKE
# 9    yahyaoui olfa  https://www.linkedin.com/in/yahyaoui-olfa-5743...     LIKE

# %%
data = pd.read_csv('results_file_big.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            309 non-null    int64
#  1   name_x                309 non-null    object
#  2   profile_title         309 non-null    object
#  3   entreprise_name       309 non-null    object
#  4   nbr_employees         309 non-null    float64
#  5   work_field            309 non-null    object
#  6   linkedin_url          309 non-null    object
#  7   reaction              309 non-null    object
#  8   region                309 non-null    object
#  9   current_job_duration  309 non-null    int64
#  10  total_experience      309 non-null    int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 26.7+ KB

# %%
data.head()
# Out:
#    Unnamed: 0             name_x  \
# 0           0     Dellou Mohamed
# 1           1          Zied MLIK
# 2           2  kochtbene khaoula
# 3           3   yesmine benrhaim
# 4           4    Abdelkrim Essid
#
#                                        profile_title  \
# 0  Étudiant à Faculté des Sciences Economiques et...
# 1                               Supply Chain Manager
# 2  I have a master in banking and  international ...
# 3           Étudiant(e) en 2MP ingénierie financière
# 4  Agent comptable chez  société les professionne...
#
#                          entreprise_name  nbr_employees       work_field  \
# 0                   Currently Unemployed            0.0       unemployed
# 1                         Délice Holding          137.0  Food Production
# 2                         ophtalmologist            0.0       unemployed
# 3                       Société jmal EJM            0.0       unemployed
# 4  société les professionnels des dattes            0.0       unemployed
#
#                                         linkedin_url reaction        region  \
# 0  https://www.linkedin.com/in/dellou-mohamed-677...     LIKE  Grand -Tunis
# 1  https://www.linkedin.com/in/zied-mlik-89117b20...     LIKE  Grand -Tunis
# 2  https://www.linkedin.com/in/kochtbene-khaoula?...     LIKE    Centre-Est
# 3  https://www.linkedin.com/in/yesmine-benrhaim-2...   PRAISE       unknown
# 4  https://www.linkedin.com/in/abdelkrim-essid-ba...     LIKE  Grand -Tunis
#
#    current_job_duration  total_experience
# 0                     0                 0
# 1                   785              4376
# 2                     0                 0
# 3                    85              1059
# 4                   334               334
